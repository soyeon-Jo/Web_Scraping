# %% [markdown]
# # 페이지 스크롤

# %%
from selenium import webdriver
browser = webdriver.Chrome()
browser.maximize_window()

url = 'https://search.naver.com/search.naver?query=%EB%A6%AC%EC%96%BC%20%ED%81%B4%EB%9E%98%EC%8A%A4%20%EB%8B%A8%EC%A0%90&nso=&where=blog&sm=tab_opt'
browser.get(url)
browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")



import time
interval = 5 #2초에 한번씩 스크롤 내림.

#현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

#반복 수행
while True:
    #스크롤 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    
    #페이지 로딩 대기
    time.sleep(interval)
    
    #현재 문서 높이를 가져와서 저장
    curr_height = browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    if curr_height == prev_height:
        break
    
    prev_height = curr_height

    page = browser.page_source
print("스크롤 완료")

import requests
from bs4 import BeautifulSoup


soup = BeautifulSoup(browser.page_source, 'lxml')
page = browser.page_source
content = []
#링크 가져오기

#겉핥기 가져오기
#paragraph = soup.find_all("div", attrs={'api_txt_lines dsc_txt'})
#for i in range(len(paragraph)):
#    print(paragraph[i].text)

# ㄹㅇ 가져오기
more_links = soup.find_all('div', {'class':'total_dsc_wrap'})
print(more_links)
# Out:
# 스크롤 완료
# ...

# %%
import requests
from bs4 import BeautifulSoup


soup = BeautifulSoup(browser.page_source, 'lxml')
page = browser.page_source
content = []
#링크 가져오기

#겉핥기 가져오기
#paragraph = soup.find_all("div", attrs={'api_txt_lines dsc_txt'})
#for i in range(len(paragraph)):
#    print(paragraph[i].text)

# ㄹㅇ 가져오기
more_links = soup.find_all('div', {'class':'total_dsc_wrap'})

for more_link in more_links: #more_link는 게시물별로 가져오기
    review_links = more_link.a['href']
    browser.get(review_links) #하나씩 들어가기
    
    review_page_soup = BeautifulSoup(page, "html.parser")
    rev_page_content = rev_page_soup.find('div', {'se-main-container'}).get_text()
    
    content.append(rev_page_content)

# %%
for more_link in more_links: #more_link는 게시물별로 가져오기
    review_links = more_link.a['href']
    
print(review_links)
# Out:
# https://blog.naver.com/zambang?Redirect=Log&logNo=222321714125

# %%
more_links
# Out:
# [<div class="total_dsc_wrap"> <a class="total_dsc" href="https://blog.naver.com/chocolata10?Redirect=Log&amp;logNo=222061274522" onclick="return goOtherCR(this, 'a=blg*a.iblg&amp;r=1&amp;i=90000003_0000000000000033B3E2259A&amp;u='+urlencode(this.href))" target="_blank"> <div class="api_txt_lines dsc_txt">그러던 중에 네이버 메인에 뜬 1년 기획의 <strong class="hl">리얼 클래스</strong> 수업을 보게 됐어요. 처음엔... 현재 6개월 성공에 7개월째 돌입 중인 제가 <strong class="hl">단점</strong>과 장점을 알려드릴께요. 장점... </div> </a> </div>,
#  <div class="total_dsc_wrap"> <a class="total_dsc" href="https://blog.naver.com/lovin_yu?Redirect=Log&amp;logNo=222334198659" onclick="return goOtherCR(this, 'a=blg*a.iblg&amp;r=2&amp;i=90000003_0000000000000033C426A383&amp;u='+urlencode(this.href))" target="_blank"> <div class="api_txt_lines dsc_txt"><strong class="hl">리얼클래스</strong> 다시 5월부터 시작... 하하... 환급 받기가 은근 어렵다. 전날 시간... 유익하고 재밌는데 귀찮다고 안 하게 되는 <strong class="hl">단점</strong>은... 게으른 내가 극복해야할.... 나의... </div> </a> </div>,
# ...

# %% [markdown]
# # 스크래핑 시작

# %% [markdown]
# import requests
# from bs4 import BeautifulSoup
#
#
# soup = BeautifulSoup(browser.page_source, 'lxml')
# content = []
# #링크 가져오기
#
# #겉핥기 가져오기
# #paragraph = soup.find_all("div", attrs={'api_txt_lines dsc_txt'})
# #for i in range(len(paragraph)):
# #    print(paragraph[i].text)
#
# # ㄹㅇ 가져오기
# more_links = soup.find_all('div', {'class':'total_dsc_wrap'})
# #print(more_links)
# print(len(more_links))
# count=0
#
# for more_link in more_links:
#     rev_link = more_link.a['href']
#
#     browser.get(rev_link) # 본문 링크 접속
#     rev_page = browser.page_source
#     rev_page_soup = BeautifulSoup(page, "html.parser")
#
#     rev_page_content = rev_page_soup.find('div', {'se-main-container'})
#
#
#
#     content.append(rev_page_content)

# %%
import pandas as pd 

content_df = pd.DataFrame(content)
content_df.to_csv()

print(pd.DataFrame(content))
# Out:
# C:\Users\82104\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\82104\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\82104\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
#        0
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# ..   ...
# 85  None
# 86  None
# 87  None
# 88  None
# 89  None
#
# [90 rows x 1 columns]

# %%
exit()
browser.quit()
